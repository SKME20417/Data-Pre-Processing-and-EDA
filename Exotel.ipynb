# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('Exotel data.csv')

# %%
df.head()
# Out:
#                                  Id     Direction           Type  ...             AppName  Digits DisconnectedBy
# 0  3dc7d25dde80a28fcf0c74786ef91635  outbound-api  transactional  ...  Automated IVR call     1.0            NaN
# 1  7080dfd61c9f9683bea03e1f641b1635  outbound-api  transactional  ...  Automated IVR call     1.0            NaN
# 2  0b24e9649efcc5e8c5bd297ba5341635  outbound-api  transactional  ...  Automated IVR call     2.0            NaN
# 3  ad413bc452a1e9b5a13dde6bb9611635  outbound-api  transactional  ...  Automated IVR call     NaN            NaN
# 4  2e7cf7dcc8fcd229aa6a3c9482921635  outbound-api  transactional  ...                 NaN     NaN            NaN
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Id', 'Direction', 'Type', 'ExotelNumber', 'From', 'FromName', 'To',
#        'ToName', 'Status', 'StartTime', 'EndTime', 'Duration', 'Price',
#        'RecordingUrl', 'PriceDetails', 'GroupName', 'FromCircle', 'ToCircle',
#        'Leg1Status', 'Leg2Status', 'ConversationDuration', 'AppID', 'AppName',
#        'Digits', 'DisconnectedBy'],
#       dtype='object')

# %%
profile1 = df.profile_report(explorative=True,dark_mode=True)

# %%
profile1.to_file('Exotel_report.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df2 = pd.read_excel("copy_data.xlsx", sheet_name="Spark&Exotel")

# %%
profile_2 = df2.profile_report(explorative = True, dark_mode = True)

# %%
profile_2.to_file("Spark and Exotel.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df3 = pd.read_excel("copy_data.xlsx", sheet_name="Call_disposition_report")

# %%
profile_3 = df3.profile_report(explorative = True, dark_mode = True)

# %%
profile_3.to_file("Call_disposition_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
pip install pandas-visual-analysis
# Out:
# ...
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=f4d2c7e025e2e6921a1bc00c9ca43b60b049efce72144c2bb1b45b7e215c8cc7
#   Stored in directory: c:\users\nimbu\appdata\local\pip\cache\wheels\50\93\f8\4f0a42a03a06626d675f13907b6982ad5ecff383530af5a900
# Successfully built blinker
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_visual_analysis

# %%
from pandas_visual_analysis import VisualAnalysis

# %%
Exotel_visual = VisualAnalysis(df)

# %%
Exotel_visual

# %%
Spark_Exotel_visual = VisualAnalysis(df2)

# %%
Spark_Exotel_visual
# Out:
# ...
# C:\Users\nimbu\anaconda3\lib\site-packages\pandas_visual_analysis\widgets\brush_summary.py:116: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %%
Call_dispotion_report = VisualAnalysis(df3)

# %%
Call_dispotion_report

# %%
df_apr = pd.read_excel("copy_data.xlsx", sheet_name="apr")

# %%
apr_visual = VisualAnalysis(df_apr)

# %%
apr_visual

# %%
pip install qgrid
# Out:
# ...
#   Created wheel for qgrid: filename=qgrid-1.3.1-py2.py3-none-any.whl size=1761271 sha256=b6497e382624dcefad054825c7b0474d5274ea73f0f3ae068945b7d419e2d9a7
#   Stored in directory: c:\users\nimbu\appdata\local\pip\cache\wheels\65\29\13\1def97680a393587b2a731261dbef083633a1586fbd785446e
# Successfully built qgrid
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pivottablejs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pivottablejs import pivot_ui

# %%
pivot_ui(df,outfile_path="Exotelpivot.html")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="Exotelpivot.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
pivot_ui(df2)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df2)

# %%
sns.pairplot(df3)

# %%
#plt.figure(figsize=(20,25))
sns.pairplot(df_apr)

# %%
pivot_ui(df3, outfile_path="Call disposition_pivot.html")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="Call disposition_pivot.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
pivot_ui(df_apr, outfile_path="APR_pivot.html")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="APR_pivot.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd

# %%
ship = pd.read_csv("Shipments_feb.csv")
# Out:
# C:\Users\nimbu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import pandas_profiling

# %%
from pandas_profiling import profile_report

# %%
ship.profile_report()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in _repr_html_(self)
#     416     def _repr_html_(self) -> None:
#     417         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 418         self.to_notebook_iframe()
#     419
#     420     def __repr__(self) -> str:
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in to_notebook_iframe(self)
#     396         with warnings.catch_warnings():
# ...
